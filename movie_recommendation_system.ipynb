# %% [markdown]
# # Content Based Movie Recommendation System

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %%
#dataset loading...
movie_df = pd.read_csv('moviedataset.csv')

# %%
movie_df.head()
# Out:
#    movie_id            Name of movie  Year of release  Rating  Votes  \
# 0         0             Sherlock Jr.             1924     8.2  43871
# 1         1       Hotarubi no mori e             2011     7.9  14884
# 2         2       Koto no ha no niwa             2013     7.5  37219
# 3         3  Blood: The Last Vampire             2000     6.7  12102
# 4         4                     Host             2020     6.5  20885
#
#                      Genre
# 0    Action,Comedy,Romance
# 1  Animation,Drama,Fantasy
# 2  Animation,Drama,Romance
# 3  Animation,Action,Horror
# 4           Horror,Mystery

# %%
# set name of movie column as the index of the dataframe 
movie_df.set_index('Name of movie')
# Out:
#                                                     movie_id  Year of release  \
# Name of movie
# Sherlock Jr.                                               0             1924
# Hotarubi no mori e                                         1             2011
# Koto no ha no niwa                                         2             2013
# Blood: The Last Vampire                                    3             2000
# Host                                                       4             2020
# L'âge d'or                                                 5             1930
# Karakomik Filmler: 2 Arada                                 6             2019
# Fear and Desire                                            7             1953
# It's Such a Beautiful Day                                  8             2012
# The Most Dangerous Game                                    9             1932
# Byôsoku 5 senchimêtoru                                    10             2007
# Winnie the Pooh                                           11             2011
# Freaks                                                    12             1932
# Dumbo                                                     13             1941
# Our Hospitality                                           14             1923
# Ma vie de Courgette                                       15             2016
# The General                                               16             1926
# Killer's Kiss                                             17             1955
# Tetsuo                                                    18             1989
# The Kid                                                   19             1921
# Horse Feathers                                            20             1932
# Detour                                                    21             1945
# The Adventures of Ichabod and Mr. Toad                    22             1949
# Astérix le Gaulois                                        23             1967
# Interstella 5555: The 5tory of the 5ecret 5tar ...        24             2003
# Duck Soup                                                 25             1933
# I Walked with a Zombie                                    26             1943
# The Land Before Time                                      27             1988
# Following                                                 28             1998
# Steamboat Bill, Jr.                                       29             1928
# ...                                                      ...              ...
# The Lord of the Rings: The Return of the King           8927             2003
# The Godfather: Part II                                  8928             1974
# Malcolm X                                               8929             1992
# Sholay                                                  8930             1975
# Andrei Rublev                                           8931             1966
# Hum Aapke Hain Koun...!                                 8932             1994
# Shichinin no samurai                                    8933             1954
# The Irishman                                            8934             2019
# It's a Mad Mad Mad Mad World                            8935             1963
# Kabhi Khushi Kabhie Gham...                             8936             2001
# Swades: We, the People                                  8937             2004
# Ben-Hur                                                 8938             1959
# Jodhaa Akbar                                            8939             2008
# Mohabbatein                                             8940             2000
# Heaven's Gate                                           8941             1980
# Gods and Generals                                       8942             2003
# The Ten Commandments                                    8943             1956
# Lagaan: Once Upon a Time in India                       8944             2001
# Lawrence of Arabia                                      8945             1962
# Once Upon a Time in America                             8946             1984
# Ai no mukidashi                                         8947             2008
# Gone with the Wind                                      8948             1939
# Hamlet                                                  8949             1996
# Zack Snyder's Justice League                            8950             2021
# Gettysburg                                              8951             1993
# Chi bi                                                  8952             2008
# Novecento                                               8953             1976
# Gangs of Wasseypur                                      8954             2012
# La meglio gioventù                                      8955             2003
# Tall Girl                                               8956             2019
#
#                                                     Rating    Votes  \
# Name of movie
# Sherlock Jr.                                           8.2    43871
# Hotarubi no mori e                                     7.9    14884
# Koto no ha no niwa                                     7.5    37219
# Blood: The Last Vampire                                6.7    12102
# Host                                                   6.5    20885
# L'âge d'or                                             7.3    13080
# Karakomik Filmler: 2 Arada                             6.4    10906
# Fear and Desire                                        5.5    10609
# It's Such a Beautiful Day                              8.3    11800
# The Most Dangerous Game                                7.1    11043
# Byôsoku 5 senchimêtoru                                 7.6    52985
# Winnie the Pooh                                        7.2    22617
# Freaks                                                 7.9    42819
# Dumbo                                                  7.2   122094
# Our Hospitality                                        7.8    10454
# Ma vie de Courgette                                    7.8    22699
# The General                                            8.1    83033
# Killer's Kiss                                          6.6    22022
# Tetsuo                                                 7.0    20359
# The Kid                                                8.3   116805
# Horse Feathers                                         7.6    12040
# Detour                                                 7.4    15844
# The Adventures of Ichabod and Mr. Toad                 7.0    13797
# Astérix le Gaulois                                     6.6    10065
# Interstella 5555: The 5tory of the 5ecret 5tar ...     7.8    13988
# Duck Soup                                              7.8    56298
# I Walked with a Zombie                                 7.1    11381
# The Land Before Time                                   7.4    81879
# Following                                              7.5    88629
# Steamboat Bill, Jr.                                    7.9    13584
# ...                                                    ...      ...
# The Lord of the Rings: The Return of the King          8.9  1678115
# The Godfather: Part II                                 9.0  1157382
# Malcolm X                                              7.7    88199
# Sholay                                                 8.2    52508
# Andrei Rublev                                          8.1    48779
# Hum Aapke Hain Koun...!                                7.5    19653
# Shichinin no samurai                                   8.6   322388
# The Irishman                                           7.8   340589
# It's a Mad Mad Mad Mad World                           7.5    38672
# Kabhi Khushi Kabhie Gham...                            7.4    46163
# Swades: We, the People                                 8.2    85327
# Ben-Hur                                                8.1   223464
# Jodhaa Akbar                                           7.6    30710
# Mohabbatein                                            7.1    27985
# Heaven's Gate                                          6.8    14068
# Gods and Generals                                      6.3    15555
# The Ten Commandments                                   7.9    65872
# Lagaan: Once Upon a Time in India                      8.1   107216
# Lawrence of Arabia                                     8.3   273460
# Once Upon a Time in America                            8.4   319491
# Ai no mukidashi                                        8.1    12374
# Gone with the Wind                                     8.1   295354
# Hamlet                                                 7.7    36417
# Zack Snyder's Justice League                           8.1   301828
# Gettysburg                                             7.6    26404
# Chi bi                                                 7.4    44279
# Novecento                                              7.7    22942
# Gangs of Wasseypur                                     8.2    86328
# La meglio gioventù                                     8.5    20965
# Tall Girl                                              5.2    18914
#
#                                                                          Genre
# Name of movie
# Sherlock Jr.                                             Action,Comedy,Romance
# Hotarubi no mori e                                     Animation,Drama,Fantasy
# Koto no ha no niwa                                     Animation,Drama,Romance
# Blood: The Last Vampire                                Animation,Action,Horror
# Host                                                            Horror,Mystery
# L'âge d'or                                                        Comedy,Drama
# Karakomik Filmler: 2 Arada                                        Comedy,Drama
# Fear and Desire                                             Drama,Thriller,War
# It's Such a Beautiful Day                               Animation,Comedy,Drama
# The Most Dangerous Game                                Action,Adventure,Horror
# Byôsoku 5 senchimêtoru                                  Animation,Drama,Family
# Winnie the Pooh                                     Animation,Adventure,Comedy
# Freaks                                                            Drama,Horror
# Dumbo                                                Animation,Adventure,Drama
# Our Hospitality                                        Comedy,Romance,Thriller
# Ma vie de Courgette                                     Animation,Comedy,Drama
# The General                                            Action,Adventure,Comedy
# Killer's Kiss                                            Crime,Drama,Film-Noir
# Tetsuo                                                   Fantasy,Horror,Sci-Fi
# The Kid                                                    Comedy,Drama,Family
# Horse Feathers                                          Comedy,Musical,Romance
# Detour                                                   Crime,Drama,Film-Noir
# The Adventures of Ichabod and Mr. Toad                 Animation,Comedy,Family
# Astérix le Gaulois                                  Animation,Action,Adventure
# Interstella 5555: The 5tory of the 5ecret 5tar ...  Animation,Action,Adventure
# Duck Soup                                                   Comedy,Musical,War
# I Walked with a Zombie                                    Drama,Fantasy,Horror
# The Land Before Time                                 Animation,Adventure,Drama
# Following                                               Crime,Mystery,Thriller
# Steamboat Bill, Jr.                                        Action,Comedy,Drama
# ...                                                                        ...
# The Lord of the Rings: The Return of the King           Action,Adventure,Drama
# The Godfather: Part II                                             Crime,Drama
# Malcolm X                                              Biography,Drama,History
# Sholay                                                 Action,Adventure,Comedy
# Andrei Rublev                                          Biography,Drama,History
# Hum Aapke Hain Koun...!                                   Comedy,Drama,Musical
# Shichinin no samurai                                    Action,Adventure,Drama
# The Irishman                                             Biography,Crime,Drama
# It's a Mad Mad Mad Mad World                           Action,Adventure,Comedy
# Kabhi Khushi Kabhie Gham...                              Drama,Musical,Romance
# Swades: We, the People                                                   Drama
# Ben-Hur                                                Adventure,Drama,History
# Jodhaa Akbar                                              Action,Drama,History
# Mohabbatein                                              Musical,Drama,Romance
# Heaven's Gate                                          Adventure,Drama,Western
# Gods and Generals                                      Biography,Drama,History
# The Ten Commandments                                           Adventure,Drama
# Lagaan: Once Upon a Time in India                          Drama,Musical,Sport
# Lawrence of Arabia                                   Adventure,Biography,Drama
# Once Upon a Time in America                                        Crime,Drama
# Ai no mukidashi                                            Action,Comedy,Drama
# Gone with the Wind                                       Drama,History,Romance
# Hamlet                                                                   Drama
# Zack Snyder's Justice League                          Action,Adventure,Fantasy
# Gettysburg                                                   Drama,History,War
# Chi bi                                                  Action,Adventure,Drama
# Novecento                                                        Drama,History
# Gangs of Wasseypur                                         Action,Comedy,Crime
# La meglio gioventù                                               Drama,Romance
# Tall Girl                                                  Comedy,Drama,Family
#
# [8957 rows x 5 columns]

# %%
movie_df.shape
# Out:
# (8957, 6)

# %%
# dropping the rows which having null values
movie_df.dropna(inplace=True)

# %%
movie_df.isnull().sum()
# Out:
# movie_id           0
# Name of movie      0
# Year of release    0
# Rating             0
# Votes              0
# Genre              0
# dtype: int64

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8957 entries, 0 to 8956
# Data columns (total 6 columns):
# movie_id           8957 non-null int64
# Name of movie      8957 non-null object
# Year of release    8957 non-null int64
# Rating             8957 non-null float64
# Votes              8957 non-null int64
# Genre              8957 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 489.8+ KB

# %%
# creating genre dataframe along with movies name as a index
genre = pd.DataFrame(data=movie_df[['Name of movie','Genre']])
genre.set_index('Name of movie',inplace=True)

# %%
genre.head(5)
# Out:
#                                            Genre
# Name of movie
# Sherlock Jr.               Action,Comedy,Romance
# Hotarubi no mori e       Animation,Drama,Fantasy
# Koto no ha no niwa       Animation,Drama,Romance
# Blood: The Last Vampire  Animation,Action,Horror
# Host                              Horror,Mystery

# %%
# Assigning the countvectorizer 
count = CountVectorizer()
count_matrix = count.fit_transform(genre['Genre'])

# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Training the recommendation system
movie_name = list(movie_df['Name of movie'])
movie_name
# Out:
# ['Sherlock Jr.',
#  'Hotarubi no mori e',
#  'Koto no ha no niwa',
#  'Blood: The Last Vampire',
#  'Host',
#  "L'âge d'or",
#  'Karakomik Filmler: 2 Arada',
#  'Fear and Desire',
#  "It's Such a Beautiful Day",
#  'The Most Dangerous Game',
#  'Byôsoku 5 senchimêtoru',
#  'Winnie the Pooh',
#  'Freaks',
#  'Dumbo',
#  'Our Hospitality',
#  'Ma vie de Courgette',
#  'The General',
#  "Killer's Kiss",
#  'Tetsuo',
#  'The Kid',
#  'Horse Feathers',
#  'Detour',
#  'The Adventures of Ichabod and Mr. Toad',
#  'Astérix le Gaulois',
#  'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem',
#  'Duck Soup',
#  'I Walked with a Zombie',
#  'The Land Before Time',
#  'Following',
#  'Steamboat Bill, Jr.',
#  'Frankenstein',
#  'The Wolf Man',
#  'Bambi',
#  'Manos: The Hands of Fate',
#  'Une vie de chat',
#  'The Invisible Man',
#  'The Three Caballeros',
#  '9 Songs',
#  'The Secret of Kells',
#  'The Party',
#  'The Circus',
#  'Animal Farm',
#  'The Little Shop of Horrors',
#  'Astérix et Cléopâtre',
#  'La planète sauvage',
#  'Begotten',
#  "We're Back! A Dinosaur's Story",
#  'Return to Never Land',
#  'The Jungle Book 2',
#  'The Mummy',
#  'Cat People',
#  'Mystery Science Theater 3000: The Movie',
#  'Safety Last!',
#  'Cinderella',
#  'Sedmikrásky',
#  'The Many Adventures of Winnie the Pooh',
#  'The Great Mouse Detective',
#  'Oliver & Company',
#  'DuckTales the Movie: Treasure of the Lost Lamp',
#  'Batman and Harley Quinn',
#  'Bronenosets Potemkin',
#  'Dracula',
#  'Vampyr',
#  'The Man Who Knew Too Much',
#  'Bride of Frankenstein',
#  'The Ox-Bow Incident',
#  'Alice in Wonderland',
#  'House on Haunted Hill',
#  'Sleeping Beauty',
#  'An American Tail: Fievel Goes West',
#  'Fantasia 2000',
#  "Happily N'Ever After",
#  'Neko no ongaeshi',
#  'Superhero Movie',
#  'Secret of the Wings',
#  'Open Season 3',
#  'Das Cabinet des Dr. Caligari',
#  'The Cameraman',
#  'Sabotage',
#  'Lady and the Tramp',
#  'Pickpocket',
#  'FernGully: The Last Rainforest',
#  'Batman: Mask of the Phantasm',
#  'The Nightmare Before Christmas',
#  'Eight Crazy Nights',
#  'Home on the Range',
#  'Valiant',
#  'Berserk: Ougon Jidai-hen I - Haou no Tamago',
#  'The Den',
#  'Batman: The Killing Joke',
#  'The Eyes of My Mother',
#  'Der letzte Mann',
#  'Monkey Business',
#  'Peter Pan',
#  'Village of the Damned',
#  'The Slumber Party Massacre',
#  'Chopping Mall',
#  'The Rescuers Down Under',
#  'Corpse Bride',
#  'Dudley Do-Right',
#  'The Tigger Movie',
#  'Stuart Little 2',
#  'Baise-moi',
#  'Köyden Indim Sehire',
#  'Loving Annabelle',
#  'Terkel i knibe',
#  'Primer',
#  'Ils',
#  'The Girlfriend Experience',
#  'Polytechnique',
#  'Creep',
#  'Zombeavers',
#  'Germania anno zero',
#  'The Lavender Hill Mob',
#  'Carnival of Souls',
#  'The Jungle Book',
#  'The AristoCats',
#  'Fritz the Cat',
#  'The Rescuers',
#  'Balto',
#  'A Goofy Movie',
#  "The Emperor's New Groove",
#  'Inspector Gadget',
#  'Rugrats in Paris: The Movie - Rugrats II',
#  'Astérix et les Vikings',
#  '[Rec]',
#  'Creep 2',
#  'Batman: Gotham by Gaslight',
#  'Yes, God, Yes',
#  'Little Caesar',
#  'Creature from the Black Lagoon',
#  'The Wild One',
#  'Plan 9 from Outer Space',
#  'House of Usher',
#  'One Hundred and One Dalmatians',
#  'The Sword in the Stone',
#  'Zelig',
#  'Silent Night, Deadly Night',
#  'Astérix chez les Bretons',
#  'The Monster Squad',
#  'Showdown in Little Tokyo',
#  'PCU',
#  'James and the Giant Peach',
#  'The Rugrats Movie',
#  'Open Water',
#  '9',
#  'Murder Party',
#  '6 Years',
#  'The Overnight',
#  'Saving Christmas',
#  'Grandma',
#  "The Devil's Candy",
#  'Rope',
#  'Pickup on South Street',
#  'Invasion of the Body Snatchers',
#  'The Pit and the Pendulum',
#  'Vivre sa vie: Film en douze tableaux',
#  'Death Race 2000',
#  'The Black Cauldron',
#  'Kyûketsuki hantâ D',
#  'An American Tail',
#  'Sleepaway Camp II: Unhappy Campers',
#  'The Pagemaster',
#  "Joe's Apartment",
#  'Le dîner de cons',
#  'Süt Kardesler',
#  'Çöpçüler Krali',
#  'Les triplettes de Belleville',
#  'The Master of Disguise',
#  'Pieces of April',
#  'Garfield',
#  'Before Sunset',
#  'Hoodwinked!',
#  'Reno 911!: Miami',
#  'Chasseurs de dragons',
#  'Wendy and Lucy',
#  'Devil',
#  'Les émotifs anonymes',
#  '[Rec]³: Génesis',
#  'Carnage',
#  'Emergo',
#  'Ernest et Célestine',
#  'Flight 7500',
#  'Willow Creek',
#  'XX',
#  'La tortue rouge',
#  'Blue Jay',
#  "Mortal Kombat Legends: Scorpion's Revenge",
#  'Bad Day at Black Rock',
#  'The Incredible Shrinking Man',
#  'Shadows',
#  'Tirez sur le pianiste',
#  'Nattvardsgästerna',
#  'Santa Claus Conquers the Martians',
#  'Mouchette',
#  'Another Woman',
#  "Look Who's Talking Too",
#  'Problem Child',
#  'El mariachi',
#  'Army of Darkness',
#  'Pocahontas',
#  'Toy Story',
#  'Beavis and Butt-Head Do America',
#  'Spy Hard',
#  'Lola rennt',
#  'Pâfekuto burû',
#  'South Park: Bigger, Longer & Uncut',
#  'Superstar',
#  'Phone Booth',
#  'The Blair Witch Project',
#  'Sugar & Spice',
#  'Kung Pow: Enter the Fist',
#  'Pootie Tang',
#  'Ice Age',
#  'From Justin to Kelly',
#  'Elephant',
#  'The Squid and the Whale',
#  'Chicken Little',
#  'Daniel der Zauberer',
#  'Space Chimps',
#  'Brüno',
#  'The Poughkeepsie Tapes',
#  'Jonah Hex',
#  'Yogi Bear',
#  'The Sitter',
#  'Alexander and the Terrible, Horrible, No Good, Very Bad Day',
#  'Excision',
#  'Smashed',
#  'Sleepwalk with Me',
#  'The Gallows',
#  'V/H/S Viral',
#  'Lights Out',
#  "J'ai perdu mon corps",
#  'The Petrified Forest',
#  'Dracula',
#  'Kavkazskaya plennitsa, ili Novye priklyucheniya Shurika',
#  'Bananas',
#  "Les 12 travaux d'Astérix",
#  'Wizards',
#  'The Secret of NIMH',
#  'This Is Spinal Tap',
#  'The Purple Rose of Cairo',
#  'The Toxic Avenger',
#  'The Little Rascals',
#  'Dirty Work',
#  'Half Baked',
#  'A Night at the Roxbury',
#  'Dinosaur',
#  'Lake Placid',
#  'Kevin & Perry Go Large',
#  'Jimmy Neutron: Boy Genius',
#  'Orange County',
#  'The Cat in the Hat',
#  'Edmond',
#  'Garfield: A Tale of Two Kitties',
#  '10 Items or Less',
#  "À l'intérieur",
#  "Trick 'r Treat",
#  'Splinter',
#  'The Final Destination',
#  'Cats & Dogs: The Revenge of Kitty Galore',
#  'Columbus Circle',
#  'Rubber',
#  'Vampires Suck',
#  'The Collection',
#  'Tomboy',
#  'Scenic Route',
#  'Ida',
#  'Visions',
#  'Terrifier',
#  'Taxi',
#  'Emelie',
#  'Hush',
#  'Wheelman',
#  'Between Two Ferns: The Movie',
#  'The Public Enemy',
#  'Trouble in Paradise',
#  'Snow White and the Seven Dwarfs',
#  'Bud Abbott Lou Costello Meet Frankenstein',
#  'D.O.A.',
#  'Old Yeller',
#  'Faster, Pussycat! Kill! Kill!',
#  'Dark Star',
#  'Robin Hood',
#  'The Texas Chain Saw Massacre',
#  'The Kentucky Fried Movie',
#  'Attack of the Killer Tomatoes!',
#  'The Fox and the Hound',
#  'Police Academy 3: Back in Training',
#  'Khane-ye doust kodjast?',
#  'The Little Mermaid',
#  'Henry: Portrait of a Serial Killer',
#  'Career Opportunities',
#  'Naked Gun 33 1/3: The Final Insult',
#  'Police Academy: Mission to Moscow',
#  'The Doom Generation',
#  'Kôkaku Kidôtai',
#  'Antz',
#  'Spirit: Stallion of the Cimarron',
#  'Universal Soldier: The Return',
#  "Dude, Where's My Car?",
#  'Kibar Feyzo',
#  'Scary Movie 2',
#  'Over the Hedge',
#  'Scary Movie 4',
#  'Deuce Bigalow: European Gigolo',
#  'The Man',
#  'An American Haunting',
#  'Date Movie',
#  'Frequently Asked Questions About Time Travel',
#  'College Road Trip',
#  'The Wolf of Snow Hollow',
#  'Dance Flick',
#  'Kôkaku kidôtai 2.0',
#  'The Angriest Man in Brooklyn',
#  'The Apparition',
#  'Get a Job',
#  'The Devil Inside',
#  'Jeff, Who Lives at Home',
#  '30 Minutes or Less',
#  'The Art of Getting By',
#  'The Dictator',
#  'Piranha 3DD',
#  'Paranormal Activity 3',
#  'Demonic',
#  'The Possession of Michael King',
#  'They Came Together',
#  'The Starving Games',
#  'The Lazarus Effect',
#  'Planes: Fire & Rescue',
#  'Grimsby',
#  'Parallels',
#  "Don't Hang Up",
#  'Unfriended',
#  'The Young Offenders',
#  'Like a Boss',
#  'Shadow in the Cloud',
#  'The Killing',
#  'The Last House on the Left',
#  'Sleepaway Camp',
#  'Broadway Danny Rose',
#  'When the Wind Blows',
#  "She's Gotta Have It",
#  'The Transformers: The Movie',
#  'Evil Dead II',
#  'Brain Damage',
#  'Krótki film o zabijaniu',
#  'All Dogs Go to Heaven',
#  'Police Academy 6: City Under Siege',
#  "Child's Play 2",
#  'Beauty and the Beast',
#  'Hot Shots!',
#  '3 Ninjas',
#  'Passenger 57',
#  'Tom and Jerry: The Movie',
#  'Homeward Bound: The Incredible Journey',
#  'Loaded Weapon 1',
#  'Bulletproof',
#  'The Crow: City of Angels',
#  'Waiting for Guffman',
#  'Chicken Run',
#  'Disturbing Behavior',
#  'Pi',
#  'Stuart Little',
#  'Romance',
#  'Gekijô-ban poketto monsutâ: Maboroshi no pokemon: Rugia bakutan',
#  'Awake',
#  'The Ladies Man',
#  'Le placard',
#  'Kapicilar Krali',
#  'The Sweetest Thing',
#  'The Animal',
#  'Bubble Boy',
#  'Bijitâ Q',
#  'Wrong Turn',
#  'Taxi 3',
#  'Scary Movie 3',
#  'Torque',
#  'Paparazzi',
#  'Spy Kids 3: Game Over',
#  'Gnomeo & Juliet',
#  'Idiocracy',
#  'Hell Ride',
#  'Little Manhattan',
#  'Banlieue 13',
#  'Conversations with Other Women',
#  'See No Evil',
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  "Let's Go to Prison",
#  'The Hitcher',
#  'Code Name: The Cleaner',
#  'Interview',
#  'Chapter 27',
#  'My Name Is Bruce',
#  'Shrooms',
#  'Howl',
#  'Next Day Air',
#  'The Children',
#  'Black Dynamite',
#  'The Loved Ones',
#  'Rare Exports',
#  'Dream House',
#  'À bout portant',
#  'New Kids Turbo',
#  'The Bay',
#  'Comme un chef',
#  'No Good Deed',
#  'Final Girl',
#  'Hidden',
#  'Contracted',
#  'The Conspiracy',
#  'Paranormal Activity: The Marked Ones',
#  'Mistress America',
#  'Obvious Child',
#  'Slow West',
#  'We Are Still Here',
#  'Under the Shadow',
#  'Gully',
#  'Teen Titans Go! To the Movies',
#  'Saint Maud',
#  'Jexi',
#  'The Gunfighter',
#  'Los olvidados',
#  'High Noon',
#  'The War of the Worlds',
#  'Une femme est une femme',
#  'Persona',
#  'Take the Money and Run',
#  'Play It Again, Sam',
#  'Love and Death',
#  'Airplane II: The Sequel',
#  'The Evil Dead',
#  'No Retreat, No Surrender',
#  'From Beyond',
#  'Amazon Women on the Moon',
#  'The Gate',
#  'Maniac Cop',
#  'The Naked Gun: From the Files of Police Squad!',
#  'Cry-Baby',
#  'Leatherface: Texas Chainsaw Massacre III',
#  'The Naked Gun 2½: The Smell of Fear',
#  'The Muppet Christmas Carol',
#  'Shadows and Fog',
#  'Hellraiser: Bloodline',
#  'The Castle',
#  'Doctor Dolittle',
#  "But I'm a Cheerleader",
#  'Big Trouble',
#  'Stealing Harvard',
#  'Lilo & Stitch',
#  'The Wild Thornberrys Movie',
#  'Swimfan',
#  'Ali G Indahouse',
#  'Havoc',
#  'Friday After Next',
#  'Dead End',
#  'Tais-toi!',
#  'The Curse of the Were-Rabbit',
#  'Brother Bear',
#  'Dumb and Dumberer: When Harry Met Lloyd',
#  'Creep',
#  'Red Eye',
#  "Surf's Up",
#  'Flushed Away',
#  'The Return',
#  'The Benchwarmers',
#  'Stay Alive',
#  'Unknown',
#  'Vacancy',
#  'Amusement',
#  'Shutter',
#  'The Foot Fist Way',
#  'Smiley Face',
#  'The Dead Girl',
#  'Carriers',
#  'Paranoid Park',
#  'Naissance des pieuvres',
#  'I Sell the Dead',
#  'Cloverfield',
#  'Dragonball Evolution',
#  '[Rec]²',
#  'Hatchet II',
#  'The Strangers: Prey at Night',
#  "Gulliver's Travels",
#  'Rampage',
#  'The Shrine',
#  'Casa de mi Padre',
#  'Absolutely Anything',
#  'Setup',
#  'The Campaign',
#  'The Nut Job',
#  'Rapture-Palooza',
#  'Vehicle 19',
#  'For a Good Time, Call...',
#  'The Purge',
#  'Dragon Ball Z: Doragon bôru Z - Kami to Kami',
#  'Afflicted',
#  'Fruitvale Station',
#  'Locke',
#  'The Grinch',
#  'Shaun the Sheep Movie',
#  'The Hungover Games',
#  'Astérix: Le domaine des dieux',
#  'The Babysitter',
#  '12 Feet Deep',
#  'Mid90s',
#  'Wonder Park',
#  'Action Point',
#  'Den skyldige',
#  'Batman Ninja',
#  'Christmas in the Wild',
#  'The 39 Steps',
#  'Brief Encounter',
#  'Jeux interdits',
#  'Scrooge',
#  'The Blob',
#  'The Raven',
#  'The Last Man on Earth',
#  'THX 1138',
#  'Ko to tamo peva',
#  'Up in Smoke',
#  'Heavy Metal',
#  'Quella villa accanto al cimitero',
#  'Critters',
#  'Friday the 13th Part VI: Jason Lives',
#  'Critters 2',
#  'Neco z Alenky',
#  'Pumpkinhead',
#  'Tonari no Totoro',
#  'Blind Fury',
#  'Cyborg',
#  'Critters 3',
#  'Buffy the Vampire Slayer',
#  'Hot Shots! Part Deux',
#  'Ace Ventura: Pet Detective',
#  'Thumbelina',
#  'High School High',
#  'Liar Liar',
#  'Halloween H20: 20 Years Later',
#  'Quest for Camelot',
#  'The Iron Giant',
#  'Taxi',
#  'Head Over Heels',
#  'Slackers',
#  'Corky Romano',
#  "My Boss's Daughter",
#  'Welcome to Collinwood',
#  'Tape',
#  'Undercover Brother',
#  'Darkness Falls',
#  "Malibu's Most Wanted",
#  '11:14',
#  'Dirty Dancing: Havana Nights',
#  'Madagascar',
#  'Walking Tall',
#  'Soul Plane',
#  'Rebound',
#  'My Summer of Love',
#  'The Onion Movie',
#  'Open Season',
#  'Horton Hears a Who!',
#  'Aqua Teen Hunger Force Colon Movie Film for Theaters',
#  "Shoot 'Em Up",
#  'For Your Consideration',
#  'The Strangers',
#  'Big Nothing',
#  'Aliens in the Attic',
#  'Epic Movie',
#  'The Promotion',
#  'Extreme Movie',
#  'Once',
#  'Cabin Fever 2: Spring Fever',
#  'XXY',
#  'Lesbian Vampire Killers',
#  'Red Dot',
#  'Beastly',
#  'Paranormal Activity',
#  'Ninja',
#  'Observe and Report',
#  'Shimmer Lake',
#  'The Lorax',
#  'Kaboom',
#  'Knights of Badassdom',
#  'The Addams Family',
#  'Hobo with a Shotgun',
#  'Fun Size',
#  'Quarantine 2: Terminal',
#  'Like Crazy',
#  'No One Lives',
#  'Silent House',
#  'Apollo 18',
#  'Safety Not Guaranteed',
#  'Oh Boy',
#  'Chernobyl Diaries',
#  'The Longest Week',
#  'Elvis & Nixon',
#  'Two Night Stand',
#  'A Haunted House',
#  'Sherlock Gnomes',
#  'Frances Ha',
#  'Point Blank',
#  'The Town That Dreaded Sundown',
#  'A Haunted House 2',
#  'The Autopsy of Jane Doe',
#  'What We Do in the Shadows',
#  'Deathgasm',
#  'The Shallows',
#  'Mayhem',
#  'Downhill',
#  'The Emoji Movie',
#  'The Secret Life of Pets 2',
#  'Quo vado?',
#  'Mom and Dad',
#  'Doua lozuri',
#  'The Possession of Hannah Grace',
#  'A Shaun the Sheep Movie: Farmageddon',
#  'Acts of Violence',
#  'Yes Day',
#  'The Lovebirds',
#  'Brahms: The Boy II',
#  'Mosul',
#  'Bad Trip',
#  'City Lights',
#  'Modern Times',
#  'The Lady from Shanghai',
#  'Letter from an Unknown Woman',
#  'Gun Crazy',
#  'The Thing from Another World',
#  'La maschera del demonio',
#  "A Hard Day's Night",
#  'Shivers',
#  'Silent Movie',
#  'Maniac',
#  "...E tu vivrai nel terrore! L'aldilà",
#  'Friday the 13th Part 2',
#  'Videodrome',
#  'The Woman in Red',
#  "A Nightmare on Elm Street Part 2: Freddy's Revenge",
#  'Police Academy 2: Their First Assignment',
#  'The Stuff',
#  'Summer Rental',
#  'Cobra',
#  "Child's Play",
#  'Krótki film o milosci',
#  'Beethoven',
#  'Stop! Or My Mom Will Shoot',
#  'Body Snatchers',
#  'The Good Son',
#  'Jason Goes to Hell: The Final Friday',
#  'North',
#  'The Return of the Texas Chainsaw Massacre',
#  'Halloween: The Curse of Michael Myers',
#  'Black Sheep',
#  'Bordello of Blood',
#  "Knockin' on Heaven's Door",
#  'Mr. Magoo',
#  'The Replacement Killers',
#  "Jane Austen's Mafia!",
#  'Wrongfully Accused',
#  'Thursday',
#  'Pecker',
#  'Highlander: Endgame',
#  'Jawbreaker',
#  'Muppets from Space',
#  'Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni',
#  'Cecil B. Demented',
#  'Get Over It',
#  'Down to Earth',
#  'Cats & Dogs',
#  'Dr. Dolittle 2',
#  'Freddy Got Fingered',
#  'Der Schuh des Manitu',
#  'Storytelling',
#  'Hababam Sinifi',
#  'View from the Top',
#  '2001 Maniacs',
#  'The One',
#  'Sennen joyû',
#  'The SpongeBob SquarePants Movie',
#  '(T)Raumschiff Surprise - Periode 1',
#  'The Woodsman',
#  'Criminal',
#  'Curious George',
#  'Seed of Chucky',
#  'Transporter 2',
#  'DOA: Dead or Alive',
#  'Love Wrecked',
#  'Tekken',
#  'Mr. Woodcock',
#  'Fantastic Mr. Fox',
#  'TMNT',
#  'When a Stranger Calls',
#  'Chaos Theory',
#  'The Simpsons Movie',
#  'Igor',
#  'One Missed Call',
#  'Strange Wilderness',
#  'The Man from Earth',
#  'Black Sheep',
#  'The Deaths of Ian Stone',
#  'The Love Guru',
#  'The Uninvited',
#  'Lake Mungo',
#  'Priest',
#  'Hoodwinked Too! Hood vs. Evil',
#  'Please Give',
#  'Young People Fucking',
#  'Dance of the Dead',
#  'Bikur Ha-Tizmoret',
#  'Meet the Spartans',
#  'Frankenweenie',
#  'Disaster Movie',
#  'Rogues Gallery',
#  'The Last Exorcism',
#  'Table 19',
#  'The Human Race',
#  'Cedar Rapids',
#  'Flypaper',
#  'Boy',
#  'Absentia',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Sound of My Voice',
#  'The Day',
#  'Le gamin au vélo',
#  'Bachelorette',
#  'Amityville: The Awakening',
#  'These Final Hours',
#  'The Secret Life of Pets',
#  'Welcome to Me',
#  'Hot Pursuit',
#  'Mandariinid',
#  'Circle',
#  'Honeymoon',
#  'Incarnate',
#  'Popstar: Never Stop Never Stopping',
#  'Nine Lives',
#  'Storks',
#  'Time Trap',
#  'Acts of Vengeance',
#  'Destination Wedding',
#  'Reign of the Supermen',
#  'Aterrados',
#  'Crawl',
#  'Avengement',
#  'The Assistant',
#  'Gretel & Hansel',
#  'Pinocchio',
#  'The Magnificent Ambersons',
#  'The Palm Beach Story',
#  'Laura',
#  'Rashomon',
#  'House of Wax',
#  'Paths of Glory',
#  'The 7th Voyage of Sinbad',
#  'The Producers',
#  'And Now for Something Completely Different',
#  'Conquest of the Planet of the Apes',
#  'Dzhentlmeny udachi',
#  'Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#  'Joe Kidd',
#  'Westworld',
#  'The Wicker Man',
#  'Flåklypa Grand Prix',
#  'Hausu',
#  'Mad Max',
#  'Airplane!',
#  "Dead Men Don't Wear Plaid",
#  "A Midsummer Night's Sex Comedy",
#  'C.H.U.D.',
#  'Dèmoni',
#  'Hobgoblins',
#  'Armed and Dangerous',
#  'Lung hing foo dai',
#  'Night of the Creeps',
#  'House II: The Second Story',
#  'Police Academy 4: Citizens on Patrol',
#  'Radio Days',
#  'Revenge of the Nerds II: Nerds in Paradise',
#  'Throw Momma from the Train',
#  'Friday the 13th Part VII: The New Blood',
#  'Halloween 4: The Return of Michael Myers',
#  "I'm Gonna Git You Sucka",
#  'Killer Klowns from Outer Space',
#  'License to Drive',
#  'Mujeres al borde de un ataque de "nervios"',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'Encino Man',
#  'Stay Tuned',
#  'Coneheads',
#  'The Lion King',
#  'Dracula: Dead and Loving It',
#  'Welcome to the Dollhouse',
#  'Bio-Dome',
#  'Dunston Checks In',
#  'Homeward Bound II: Lost in San Francisco',
#  'Space Jam',
#  'Beverly Hills Ninja',
#  'Mulan',
#  'Tarzan',
#  'Men in Black II',
#  'Sinbad: Legend of the Seven Seas',
#  'Scary Movie',
#  'Taxi 2',
#  'Just Visiting',
#  'Deuce Bigalow: Male Gigolo',
#  'Spy Kids',
#  'The New Guy',
#  'Big Fat Liar',
#  'Jalla! Jalla!',
#  'Superbabies: Baby Geniuses 2',
#  'National Security',
#  'Darkness',
#  'The Medallion',
#  'Old School',
#  'The Big Bounce',
#  'Harold & Kumar Go to White Castle',
#  'Four Christmases',
#  'Ultraviolet',
#  'Calvaire',
#  'Bin-jip',
#  'The Ant Bully',
#  'Friends with Money',
#  'G-Force',
#  'Yours, Mine & Ours',
#  'Altered',
#  'Piranha 3D',
#  'Wristcutters: A Love Story',
#  'Crank',
#  'Miss Potter',
#  'Jumper',
#  'Hot Rod',
#  'Scary Movie 5',
#  'The Babysitters',
#  'Sleuth',
#  'Red State',
#  'Cleaner',
#  'Armored',
#  'Prom Night',
#  'Cheung gong 7 hou',
#  'The Other Man',
#  'Old Dogs',
#  'Dou foh sin',
#  'The Rental',
#  'Transit',
#  'The Unborn',
#  'Post Grad',
#  'Zombieland',
#  'Alvin and the Chipmunks: The Squeakquel',
#  'Date Night',
#  'Mars Needs Moms',
#  'A.C.O.D.',
#  'Cockneys vs Zombies',
#  'Hansel & Gretel: Witch Hunters',
#  'The Pirates! In an Adventure with Scientists!',
#  'Attack the Block',
#  'Underworld: Awakening',
#  'The Oogieloves in the Big Balloon Adventure',
#  'Violet & Daisy',
#  'Project X',
#  'Ice Age: Continental Drift',
#  'Twixt',
#  "It's a Disaster",
#  'Sightseers',
#  'The Last Exorcism Part II',
#  'Paranormal Activity 4',
#  'Runner Runner',
#  'Cheap Thrills',
#  'The Peanuts Movie',
#  'Paranormal Activity: The Ghost Dimension',
#  'Cooties',
#  "God's Pocket",
#  'Last Shift',
#  'Man Up',
#  'Security',
#  'Blood Father',
#  'Brain on Fire',
#  'The Hollars',
#  'The Escort',
#  'Cop Car',
#  'Tangerine',
#  'Yoga Hosers',
#  "Don't Breathe",
#  'The Wall',
#  'Beta Test',
#  'The House',
#  'The Layover',
#  'Polaroid',
#  'ARQ',
#  'Lucky',
#  'Breaking In',
#  "Willy's Wonderland",
#  'An American Pickle',
#  'Coffee & Kareem',
#  '42nd Street',
#  "L'Atalante",
#  'Ladri di biciclette',
#  'Sorry, Wrong Number',
#  'Umberto D.',
#  'The Big Heat',
#  'All That Heaven Allows',
#  'Jungfrukällan',
#  'The Masque of the Red Death',
#  'Silent Running',
#  'Sleeper',
#  'Eraserhead',
#  'Phantasm',
#  'The Fog',
#  'Stardust Memories',
#  'Death Wish II',
#  'Stranger Than Paradise',
#  'Red Sonja',
#  "April Fool's Day",
#  'Stand by Me',
#  'Jaws: The Revenge',
#  'The Stepfather',
#  'Hotaru no haka',
#  'Return of the Living Dead: Part II',
#  'A Nightmare on Elm Street: The Dream Child',
#  'The Punisher',
#  'Death Warrant',
#  'Graveyard Shift',
#  'Quick Change',
#  "Freddy's Dead: The Final Nightmare",
#  'Honey, I Blew Up the Kid',
#  "Beethoven's 2nd",
#  'The Crush',
#  'Shallow Grave',
#  'Billy Madison',
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#  'Jingle All the Way',
#  'Anaconda',
#  'The Avengers',
#  'Bean',
#  'The Borrowers',
#  'Bacheha-Ye aseman',
#  'Gummo',
#  'The Road to El Dorado',
#  'Bride of Chucky',
#  'Fucking Åmål',
#  'Office Space',
#  'The Limey',
#  'Snow Day',
#  'Sexy Beast',
#  'Wo de fu qin mu qin',
#  'Domestic Disturbance',
#  'House of 1000 Corpses',
#  'Out Cold',
#  'Kangaroo Jack',
#  'Duplex',
#  'Scooby-Doo',
#  'Johnny English',
#  'Not Another Teen Movie',
#  'Elling',
#  'They',
#  'Swept Away',
#  'The Station Agent',
#  'Boogeyman',
#  'Confessions of a Teenage Drama Queen',
#  'A Dirty Shame',
#  'Sleepover',
#  'Speak',
#  'Gambit',
#  'Kidulthood',
#  'Dead Silence',
#  'John Tucker Must Die',
#  'The Only Living Boy in New York',
#  'Daddy Day Camp',
#  'Larry the Cable Guy: Health Inspector',
#  'Madagascar: Escape 2 Africa',
#  'Escape from Planet Earth',
#  'The Hills Have Eyes II',
#  'Bride Wars',
#  'Surrogates',
#  'La habitación de Fermat',
#  'Doghouse',
#  'The Belko Experiment',
#  'Quarantine',
#  'Megan Is Missing',
#  'The Goods: Live Hard, Sell Hard',
#  'The Darkest Hour',
#  'Gentlemen Broncos',
#  'Ouija',
#  'Rambo: Last Blood',
#  'Five Minutes of Heaven',
#  'The Ward',
#  'Tucker and Dale vs Evil',
#  'Spy Kids 4: All the Time in the World',
#  'Blair Witch',
#  'Ronal Barbaren',
#  'Hell',
#  'The Decoy Bride',
#  'The Numbers Station',
#  'Sausage Party',
#  'Chronicle',
#  "I Don't Know How She Does It",
#  'Extracted',
#  'Aftershock',
#  'Meeting Evil',
#  'A Case of You',
#  'Robot & Frank',
#  ...]

# %%
def fullname(partial):
    return_list=[]
    for name in movie_name:
        a = partial.lower().split()
        count = 0
        for i in a:
            if name.lower().find(i) > -1:
                count = count+1
        if count==len(a):
            return_list.append(name)
    if partial in return_list:
        return partial
    else:
        return return_list[0]

# %%
# recommendation function to give the recommendation on the basis of genre and the highest votes.
def get_recommendation(title, cosine_sim = cosine_sim):
    name = fullname(title)
    
    recommended_movies = []

    idx = movie_df[movie_df['Name of movie']==name].index[0]

    # creating a Series with the similarity scores in descending order
    score_df = pd.DataFrame(cosine_sim[idx],columns=['score'])
    
    score_df=score_df.join(movie_df['Votes'])
    score_df=score_df.join(movie_df['Name of movie'])
    
    score_df = score_df[(score_df['Votes']>100000)].sort_values('score',ascending=False)

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_df.iloc[1:11].index)
    
    # getting the top 10 movies names and appending the given movie name at the starting
    top_10_movies=[name]+list(movie_df['Name of movie'].iloc[top_10_indexes])

    
        
    return top_10_movies

# %%
a=get_recommendation('Dracula')
a
# Out:
# ['Dracula',
#  'The Wolfman',
#  'Crimson Peak',
#  'It Chapter Two',
#  'The Woman in Black',
#  'The Lighthouse',
#  'Doctor Sleep',
#  'The Tree of Life',
#  'The Shining',
#  "Rosemary's Baby",
#  'Carrie']

# %%
import dill

# %%
dill.settings['recurse'] = True

# %%
dill_out = open("recomm.pkl","wb")
dill.dump(get_recommendation,dill_out)

# %%
dill_out.close()
